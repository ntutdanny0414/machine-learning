# %%
import pandas as pd

# %%
df = pd.read_csv('TAIPEIDATA1.csv').set_index('序號')

# %%
df2 = pd.read_csv('TAIPEIDATA2.csv').set_index('序號')

# %%
df
# Out:
#        測站        監測日期      監測時間 測站氣壓(hPa)  溫度(℃)  相對溼度(%)   風向  風速(m/s)  \
# 序號
# 1      臺北  2016/04/01  23:04:00   1,012.4   21.0       73  NaN      0.7
# 2      臺北  2016/04/01  22:04:00   1,012.6   21.0       73  NaN      0.9
# 3      臺北  2016/04/01  21:04:00   1,012.4   21.2       71  NaN      1.4
# 4      臺北  2016/04/01  20:04:00     1,012   21.4       70  NaN      2.1
# 5      臺北  2016/04/01  19:04:00   1,011.4   21.4       69  NaN      2.7
# 6      臺北  2016/04/01  18:04:00   1,011.1   21.7       67  NaN      3.0
# 7      臺北  2016/04/01  17:04:00   1,010.9   22.0       65  NaN      3.3
# 8      臺北  2016/04/01  16:04:00   1,010.6   22.2       65  NaN      4.4
# 9      臺北  2016/04/01  15:04:00   1,010.7   22.7       64  NaN      3.7
# 10     臺北  2016/04/01  14:04:00   1,011.1   22.9       64  NaN      4.1
# 11     臺北  2016/04/01  13:04:00   1,011.5   23.4       64  NaN      2.8
# 12     臺北  2016/04/01  12:04:00   1,012.1   22.9       65  NaN      3.5
# ...

# %%
df3 = df2.append(df, ignore_index=True)

# %%
df3
# Out:
#        測站        監測日期      監測時間 測站氣壓(hPa)  溫度(℃) 相對溼度(%)   風向 風速(m/s)  \
# 0      臺北  2019/05/23  23:05:00   1,009.4   24.0      84    東     3.7
# 1      臺北  2019/05/23  22:05:00   1,009.6   24.2      82    東     3.5
# 2      臺北  2019/05/23  21:05:00   1,009.4   24.3      81    東     5.1
# 3      臺北  2019/05/23  20:05:00   1,008.9   24.2      81    東       4
# 4      臺北  2019/05/23  19:05:00   1,008.1   24.5      78    東     4.5
# 5      臺北  2019/05/23  18:05:00   1,007.6   25.7      73    東     3.5
# 6      臺北  2019/05/23  17:05:00   1,007.1   26.4      70  東北東     3.2
# 7      臺北  2019/05/23  16:05:00     1,007   27.1      63  東北東     3.4
# 8      臺北  2019/05/23  15:05:00   1,007.5   27.0      61  東北東     2.4
# 9      臺北  2019/05/23  14:05:00   1,007.8   26.3      62  東北東     3.8
# 10     臺北  2019/05/23  13:05:00   1,008.4   25.4      72  東北東     3.3
# 11     臺北  2019/05/23  12:05:00   1,009.4   22.1      95  東南東     3.3
# ...

# %%
df3.to_csv('inputdata.csv',encoding = 'UTF-8',index=False)

# %%
df4 = pd.read_csv('inputdata.csv')

# %%
df4
# Out:
#        測站        監測日期      監測時間 測站氣壓(hPa)  溫度(℃) 相對溼度(%)   風向 風速(m/s)  \
# 0      臺北  2019/05/23  23:05:00   1,009.4   24.0      84    東     3.7
# 1      臺北  2019/05/23  22:05:00   1,009.6   24.2      82    東     3.5
# 2      臺北  2019/05/23  21:05:00   1,009.4   24.3      81    東     5.1
# 3      臺北  2019/05/23  20:05:00   1,008.9   24.2      81    東       4
# 4      臺北  2019/05/23  19:05:00   1,008.1   24.5      78    東     4.5
# 5      臺北  2019/05/23  18:05:00   1,007.6   25.7      73    東     3.5
# 6      臺北  2019/05/23  17:05:00   1,007.1   26.4      70  東北東     3.2
# 7      臺北  2019/05/23  16:05:00     1,007   27.1      63  東北東     3.4
# 8      臺北  2019/05/23  15:05:00   1,007.5   27.0      61  東北東     2.4
# 9      臺北  2019/05/23  14:05:00   1,007.8   26.3      62  東北東     3.8
# 10     臺北  2019/05/23  13:05:00   1,008.4   25.4      72  東北東     3.3
# 11     臺北  2019/05/23  12:05:00   1,009.4   22.1      95  東南東     3.3
# ...
